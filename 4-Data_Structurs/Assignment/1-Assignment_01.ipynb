# %% [markdown]
# # Assignment 01:

# %% [markdown]
# Details:
# Deadline = 11:00 PM 14-11-2024 Thursday
#
# * Create a copy of this notebook and solve questions.
# * Copy the link generated in the sharing settings.
# Go to the form [Submit here](https://forms.gle/stEYaVBUV7pDRrnR8).
# Paste the link in the appropriate field and submit it before the deadline (11:00 PM on 14-11-2024, Thursday).

# %% [markdown]
# ### Question 01:
# You are given the following values representing the dimensions of a rectangular box:
#
# * length = 10
# * width = 5
# * height = 8
#
# Tasks:
# 1.	Pack these values into a tuple named dimensions.
# 2.	Unpack dimensions back into three variables l, w, and h.
# 3.	Print the tuple dimensions.
# 4.	Print each unpacked variable (l, w, and h) separately.

# %% [markdown]
# **1-Pack these values into a tuple named dimensions**

# %%
dimensions = (10,5,8)

# %% [markdown]
# **2-Unpack dimensions back into three variables l, w, and h**

# %%
l, w, h = dimensions

# %% [markdown]
# **3-Print the tuple dimensions**

# %%
print(dimensions)
# Out:
# (10, 5, 8)

# %% [markdown]
# **4-Print each unpacked variable (l, w, and h) separately**

# %%
print(l)
print(w)
print(h)
# Out:
# 10
# 5
# 8

# %% [markdown]
# ### Question 02:
#
# Create a tuple named numbers with the following elements: 3, 7, 3, 8, 9, 3, 6, 8, 7, 3. Then, complete the following tasks:
#
# 1. Count the occurrences of the number 3 in the tuple and print the result.
# 2. Count the occurrences of the number 8 in the tuple and print the result.
# 3. Find the index of the first occurrence of the number 9 and print the result.
# 4. Create a new tuple by concatenating numbers with another tuple (10, 11, 12) and print the result.

# %% [markdown]
# **Create a tuple named numbers**

# %%
numbers = (3, 7, 3, 8, 9, 3, 6, 8, 7, 3)
print(numbers)
print(type(numbers))
# Out:
# (3, 7, 3, 8, 9, 3, 6, 8, 7, 3)
# <class 'tuple'>

# %% [markdown]
# **1-Count the occurrences of the number 3 in the tuple and print the result**

# %%
count_3 = numbers.count(3)
print(f'The number {3} appears in the tuple {count_3} times')
# Out:
# The number 3 appears in the tuple 4 times

# %% [markdown]
# **2-Count the occurrences of the number 8 in the tuple and print the result**

# %%
count_8 = numbers.count(8)
print(f'The number {8} appears in the tuple {count_8} times')
# Out:
# The number 8 appears in the tuple 2 times

# %% [markdown]
# **3-Find the index of the first occurrence of the number 9 and print the result**

# %%
index_9 = numbers.index(9)
print(f'The index of number {9} in tuple is {index_9}')
# Out:
# The index of number 9 in tuple is 4

# %% [markdown]
# **4-Create a new tuple by concatenating numbers with another tuple (10, 11, 12) and print the result**

# %%
tuple1 = (10,11,12)
tuple2 = numbers + tuple1
print(tuple2)
# Out:
# (3, 7, 3, 8, 9, 3, 6, 8, 7, 3, 10, 11, 12)

# %% [markdown]
# ### Question 03:
# Tasks:
# 1. Imagine you are managing a shopping list for a grocery store.
# 2. Create a list of items called shopping_list with items like "milk", "bread", "eggs", "flour", and "sugar".
# 3. Remove an item that’s already bought (your choice) and add two more items to the list.
# 4. Print the updated shopping list and its length.

# %% [markdown]
# ***1-Create a list of items called shopping_list with items ***

# %%
shopping_list = ["milk", "bread", "eggs", "flour", "sugar"]

# %% [markdown]
# **2-Remove an item that’s already bought (your choice) and add two more items to the list**

# %%
shopping_list.pop(1)

shopping_list.append('rise')
shopping_list.append('drink')

# %% [markdown]
# **4-Print the updated shopping list and its length**

# %%
print(shopping_list)
# Out:
# ['milk', 'eggs', 'flour', 'sugar', 'rise', 'drink']

# %% [markdown]
# ### Question 04:
# Start with an empty list called hobbies. Add three hobbies of your choice to this list, one at a time. Print the final list.

# %% [markdown]
# **1-Start with an empty list called hobbies**

# %%
hobbies = []

# %% [markdown]
# **2-Add three hobbies of your choice to this list, one at a time**

# %%
hobbies.append("Cricket")
hobbies.append("Games")
hobbies.append("Islamic Videos")

# %% [markdown]
# **3-Print the final list**

# %%
print(hobbies)
# Out:
# ['Cricket', 'Games', 'Islamic Videos']

# %% [markdown]
# ### Question 05:
# 1. Create a list code_numbers of numbers that represent a “code,” like `[3, 7, 5, 9, 2, 8].`
# 2. Print and store only the even numbers from the list "code_numbers" using list comprehension in new list.
# 3. Next, reverse the code_numbers list and join them with list you create on step 2 to create a new list new_numbers.
# 4. Print the new_numbers list.

# %% [markdown]
# **1-Create a list code_numbers of numbers**

# %%
code_numbers = [3, 7, 5, 9, 2, 8]

# %% [markdown]
# **2-Print and store only the even numbers from the list "code_numbers" using list comprehension in new list.**

# %%
new_list = [i for i in code_numbers if i % 2 == 0]
print(new_list)
# Out:
# [2, 8]

# %% [markdown]
# **3-Next, reverse the code_numbers list and join them with list you create on step 2 to create a new list new_numbers**

# %%
code_numbers.reverse()

new_numbers = code_numbers + new_list

# %% [markdown]
# **4-Print the new_numbers list**

# %%
print(new_numbers)
# Out:
# [8, 2, 9, 5, 7, 3, 2, 8]
