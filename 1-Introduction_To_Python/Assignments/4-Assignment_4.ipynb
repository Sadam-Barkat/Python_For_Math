# %% [markdown]
# #Question No 1

# %%
fname = input("Enter First Name : ")
print("Hello",fname)
# Out:
# Enter First Name : Sadam
# Hello Sadam

# %% [markdown]
# #Question No 2

# %%
fname = input("Enter First Name : ")
sname = input("Enter SureName : ")
print(f'Hello {fname} {sname}')
# Out:
# Enter First Name : sadam
# Enter SureName : barkat
# Hello sadam barkat

# %% [markdown]
# #Question No 3

# %%
print("""What do you call a bear with no teeth?
A gummy bear!""")
# Out:
# What do you call a bear with no teeth?
# A gummy bear!

# %% [markdown]
# #Question No 4

# %%
a = int(input("Enter first no : "))
b = int(input("Enter second no : "))
c = int(input("Enter third no : "))

answer = (a+b)*c
print(answer)
# Out:
# Enter first no : 1
# Enter second no : 2
# Enter third no : 3
# 9

# %% [markdown]
# #Question No 5

# %%
name = input("Enter Name : ")
age = int(input("Enter Age : "))

print(f'{name} next birthday you will be {age+1}')
# Out:
# Enter Name : sadam
# Enter Age : 24
# sadam next birthday you will be 25

# %% [markdown]
# #Question No 6

# %%
days = int(input("Enter the no of days : "))
hours = days*24
minutes = days*24*60
seconds = days*24*60*60

print(f'Days = {days}, hours = {hours}, minutes = {minutes}, seconds = {seconds}')
# Out:
# Enter the no of days : 6
# Days = 6, hours = 144, minutes = 8640, seconds = 518400

# %% [markdown]
# #Question No 7

# %%
fname = ( input("Enter First Name : ").lower())
sname = (input("Enter SureName : ").lower())
print(fname.title(),sname.title())
# Out:
# Enter First Name : SadamK
# Enter SureName : BarKat
# Sadamk Barkat

# %% [markdown]
# #Question No 8

# %%
name = input("Enter the syntax : ")
sindex = int(input("Enter the starting index : "))
eindex = int(input("Enter the ending index : "))

print(name)
print(name[sindex:eindex])
# Out:
# Enter the syntax : sadamkhan
# Enter the starting index : 0
# Enter the ending index : 3
# sadamkhan
# sad

# %% [markdown]
# #Question No 9

# %%
word = input("Enter any word : ")
print(word.upper())
# Out:
# Enter any word : sadam
# SADAM

# %% [markdown]
# #Question No 10

# %%
def reverse(a):
  return a[::-1]
reverse("sadam")
# Out:
# 'madas'
