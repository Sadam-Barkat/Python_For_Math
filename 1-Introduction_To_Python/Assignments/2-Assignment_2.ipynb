# %% [markdown]
# **1 - What Is The Purpose Of Indentation In Python?**
#
#
# 1.   Indentaion Basically used for specific block of code
# 2.   When we use indetaion it specifies that this is a sperate block of code
# 3.   If we use for loop and we print something outside the indetation it does not work according to foor loop because it compiler does not consider the part of for for loop
# e.g
# 4.  for i in range(5):
#         print(i)
#         here it print 0 because it is in the for loop
# print(i) here it is not working according to for loop
#
# **2 - How do you write a comment in Python?**
#
#
# 1.   In python there are different type of comments single line and multi-line comments
# 2.    (#)singel line commnet
# 3.   /**/ multiline comment
# 4.   ''' ''' this is also a multi-line comment

# %% [markdown]
# #Question No 3

# %%
x = 5
print(x)

# %% [markdown]
# #Question No 4

# %%
for i in range(5):
  for j in range(i):
    print('*',end='')
  print()

# %% [markdown]
# #Question No 5
#
# The out put of this code is
# ------>10,15

# %% [markdown]
# #Question no 6

# %%
name = input("Enter the name : ")
print("Hello",name)
# Out:
# Enter the name : sadam
# Hello sadam

# %% [markdown]
# #Question No 7

# %%
a = 10
b = 3.5
c = a+b
print(c)
print(type(c))
# Out:
# 13.5
# <class 'float'>

# %% [markdown]
# #Question No 8
# print(x == y) -----> False
#
# print(x == int(y))------>True
